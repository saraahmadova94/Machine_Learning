# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:80%;color:white;text-align:center;border-radius:20px 20px;"><b>Boosting_(Ada_Gradient_XGBoosting_LightGBM_CatBoost_Classifier) </b></p>

# %% [markdown]
# **Ensemble Methods: Purpose and Differences Between Bagging and Boosting**
#
# Ensemble methods aim to create a stronger meta-model by combining a series of weak learner models. These methods generally outperform a single model by leveraging the collective learning capabilities of multiple models.
#
# ---
#
# ### **Purpose of Ensemble Methods**
# - **Using Weak Learners:** Weak learners are models that individually perform poorly but can make strong predictions when combined.
# - **Building a Meta Model:** By combining the predictions of multiple weak learners, ensemble methods achieve more accurate and reliable results compared to individual models.
#
# ---
#
# ### **Bagging and Boosting**
# 1. **Bagging (Bootstrap Aggregating)**
#    - **Working Principle:** Bagging creates random subsets of the dataset and trains a separate model on each subset. Each model is trained on a different "bootstrap" sample of the data.
#    - **Characteristics:** Bagging includes algorithms like Random Forest. Each model is trained independently, and their results are combined using majority voting or averaging.
#    - **Purpose:** To reduce model variance and decrease the risk of overfitting.
#
# 2. **Boosting**
#    - **Working Principle:** Boosting trains weak learners sequentially. Each new model focuses on correcting the errors of the previous models.
#    - **Characteristics:** Boosting includes algorithms like XGBoost and AdaBoost. Models learn from each other’s mistakes, and results are combined using weighted voting or averaging.
#    - **Purpose:** To reduce both bias and variance, improving the overall performance of the model.
#
# ---
#
# ### **Application and Evaluation**
# Ensemble methods offer different approaches to improve model performance. While Bagging combats overfitting by increasing randomness and diversity, Boosting focuses on collaboration between models to produce more precise predictions.

# %% [markdown]
# **AdaBoost (Adaptive Boosting)**
#
# - **Weak Learner:** Typically uses decision stumps (one-level trees).
# - **Weighting:** Initially assigns equal weights to all data points. In each iteration, the weights of misclassified data points are increased, making subsequent weak learners focus on correcting these errors.
# - **Result:** Each weak learner is assigned a weight based on its accuracy, and the final prediction is made by summing these weighted predictions.
# - **Advantage:** Simple and fast but sensitive to noise.
#
# ---
#
# **Gradient Boosting**
#
# - **Weak Learner:** Decision trees are used, and they can be deeper.
# - **Error Reduction:** Each new model tries to correct the errors of the previous models, training on residuals.
# - **Gradient Descent:** Uses gradient descent on a loss function to minimize prediction errors.
# - **Result:** Combines the predictions of all models to make the final prediction.
# - **Advantage:** Flexible and can use different loss functions but can be slow to train.
#
# ---
#
# **XGBoost (Extreme Gradient Boosting)**
#
# - **Optimized Gradient Boosting:** An optimized version of Gradient Boosting.
# - **Speed and Efficiency:** Employs parallel computation, regularization, and more efficient tree structures for faster and better performance.
# - **Error Reduction:** Includes L1 (Lasso) and L2 (Ridge) regularization to prevent overfitting.
# - **Advantage:** Fast, suitable for large datasets, and often performs exceptionally well in competitions.
#
# ---
#
# **LightGBM (Light Gradient Boosting Machine)**
#
# - **Light and Fast:** Designed for large datasets with a focus on speed and efficiency. Uses histogram-based methods for faster computation.
# - **Tree Structure:** Employs a leaf-wise growth strategy, which deepens tree leaves for better generalization.
# - **Memory Efficiency:** Reduces memory usage with a histogram-based algorithm.
# - **Advantage:** Highly effective and fast even for very large datasets.
#
# ---
#
# **CatBoost (Categorical Boosting)**
#
# - **Categorical Data Support:** Processes categorical data directly, eliminating the need for manual encoding using techniques like target-based encoding.
# - **Overfitting Control:** Uses methods like **ordered boosting** and **L2 regularization** to prevent overfitting.
# - **Speed and Efficiency:** Supports parallel processing and GPU acceleration for faster training on large datasets.
# - **Text Features:** Automatically handles text data (supports text_features).
# - **Error Reduction:** Corrects residual errors using gradient boosting logic.
# - **Advantage:** High performance with categorical data, minimal hyperparameter tuning, and easy to use.
#
# ---
#
# **Summary**
#
# - **AdaBoost:** Suitable for simple problems and small datasets. Focuses on misclassified samples by adjusting weights; simple and fast.
# - **Gradient Boosting:** Flexible but slower; effective for small to medium-sized datasets. Corrects errors using gradient descent.
# - **XGBoost:** Optimized and faster version of Gradient Boosting; excels on large datasets.
# - **LightGBM:** Among the fastest algorithms, ideal for very large datasets and high-performance needs.
# - **CatBoost:** Optimized for categorical datasets; delivers high performance with minimal tuning and supports categorical features natively.

# %% [markdown]
# **AdaBoost**
#
# 1. **n_estimators:**
#    - **Description:** The number of weak learners to be used.
#    - **Default:** 50
#    - **Effect:** More estimators generally lead to better performance but may increase the risk of overfitting.
#
# 2. **learning_rate:**
#    - **Description:** Determines the weight of each estimator's contribution.
#    - **Default:** 1.0
#    - **Effect:** Lower learning rates result in more stable but slower learning and are typically used with more estimators.
#
# 3. **base_estimator:**
#    - **Description:** The base model used as a weak learner.
#    - **Default:** DecisionTreeClassifier(max_depth=1)
#    - **Effect:** Can be replaced with different models, but a decision stump (a one-level decision tree) is commonly used.
#
# ---
#
# **Gradient Boosting**
#
# 1. **n_estimators:**
#    - **Description:** The number of boosting stages to be used.
#    - **Default:** 100
#    - **Effect:** More estimators generally lead to better performance but may increase the risk of overfitting.
#
# 2. **learning_rate:**
#    - **Description:** Determines the contribution of each weak learner.
#    - **Default:** 0.1
#    - **Effect:** Lower learning rates, combined with more estimators, often provide better generalization.
#
# 3. **max_depth:**
#    - **Description:** Maximum depth of the decision trees.
#    - **Default:** 3
#    - **Effect:** Deeper trees increase model complexity but also the risk of overfitting.
#
# 4. **subsample:**
#    - **Description:** The fraction of samples used for each boosting stage.
#    - **Default:** 1.0 (uses all samples)
#    - **Effect:** Lower values can reduce variance and help prevent overfitting.
#
# ---
#
# **XGBoost**
#
# 1. **n_estimators:**
#    - **Description:** Number of trees or boosting rounds.
#    - **Default:** 100
#    - **Effect:** More estimators generally improve results but increase computational cost.
#
# 2. **learning_rate (eta):**
#    - **Description:** Step size shrinkage between trees.
#    - **Default:** 0.3
#    - **Effect:** Lower learning rates, combined with more iterations, typically result in better generalization.
#
# 3. **max_depth:**
#    - **Description:** Maximum depth of each decision tree.
#    - **Default:** 6
#    - **Effect:** Deeper trees can capture more complex patterns but may lead to overfitting.
#
# 4. **subsample:**
#    - **Description:** Fraction of samples used for training each tree.
#    - **Default:** 1.0
#    - **Effect:** Lower values can reduce variance and prevent overfitting.
#
# 5. **colsample_bytree:**
#    - **Description:** Fraction of features randomly selected for each tree.
#    - **Default:** 1.0
#    - **Effect:** Adding randomness can improve generalization.
#
# 6. **gamma:**
#    - **Description:** Minimum loss reduction required to split a leaf node.
#    - **Default:** 0
#    - **Effect:** Higher values lead to simpler models.
#
# ---
#
# **LightGBM**
#
# 1. **num_leaves:**
#    - **Description:** Number of leaves in each decision tree.
#    - **Default:** 31
#    - **Effect:** More leaves allow for more complex patterns but increase the risk of overfitting.
#
# 2. **learning_rate:**
#    - **Description:** Determines the contribution of each iteration.
#    - **Default:** 0.1
#    - **Effect:** Lower learning rates provide slower but more stable learning.
#
# 3. **n_estimators:**
#    - **Description:** Number of trees or boosting rounds.
#    - **Default:** 100
#    - **Effect:** More estimators generally improve results.
#
# 4. **max_depth:**
#    - **Description:** Maximum depth of decision trees.
#    - **Default:** -1 (unlimited)
#    - **Effect:** Deeper trees can learn more complex patterns but may overfit.
#
# 5. **feature_fraction:**
#    - **Description:** Fraction of features used per iteration.
#    - **Default:** 1.0
#    - **Effect:** Lower values introduce feature randomness and help prevent overfitting.
#
# 6. **bagging_fraction:**
#    - **Description:** Fraction of samples used per iteration.
#    - **Default:** 1.0
#    - **Effect:** Lower values reduce variance and prevent overfitting.
#
# 7. **lambda_l1 and lambda_l2:**
#    - **Description:** L1 and L2 regularization parameters.
#    - **Default:** 0
#    - **Effect:** Adding regularization helps control overfitting.
#
# ---
#
# **CatBoost**
#
# 1. **iterations:**
#    - **Description:** Total number of boosting stages (trees).
#    - **Default:** 1000
#    - **Effect:** More iterations generally improve results but increase training time and overfitting risk.
#
# 2. **learning_rate:**
#    - **Description:** Determines the contribution of each iteration.
#    - **Default:** Automatically tuned (usually starts around 0.03).
#    - **Effect:** Lower learning rates combined with more iterations provide better generalization.
#
# 3. **depth:**
#    - **Description:** Maximum depth of decision trees.
#    - **Default:** 6
#    - **Effect:** Deeper trees can capture more complex patterns but increase overfitting risk.
#
# 4. **l2_leaf_reg:**
#    - **Description:** L2 regularization coefficient on leaf weights.
#    - **Default:** 3.0
#    - **Effect:** Higher values reduce overfitting but may oversimplify the model.
#
# 5. **subsample:**
#    - **Description:** Fraction of samples used per boosting stage.
#    - **Default:** 1.0
#    - **Effect:** Lower values reduce variance and prevent overfitting.
#
# 6. **random_strength:**
#    - **Description:** Strength of randomness during tree construction.
#    - **Default:** 1.0
#    - **Effect:** Higher values help avoid overfitting.
#
# 7. **task_type:**
#    - **Description:** Specifies whether to run on CPU or GPU.
#    - **Default:** 'CPU'
#    - **Effect:** GPU can speed up training for large datasets.
#
# 8. **cat_features:**
#    - **Description:** List of categorical features.
#    - **Default:** Needs to be specified.
#    - **Effect:** Optimizes categorical data without manual encoding.
#
# 9. **eval_metric:**
#    - **Description:** Metric used for model evaluation.
#    - **Default:** Logloss (classification) or RMSE (regression).
#    - **Effect:** Determines model optimization criteria.
#
# 10. **early_stopping_rounds:**
#     - **Description:** Stops training if no improvement occurs for a specified number of iterations.
#     - **Default:** None
#     - **Effect:** Reduces training time and helps prevent overfitting.

# %% [markdown]
# **About Dataset**
#
# Machine Learning Model for Predicting Ad Clicks
#
#
# * 'Daily Time Spent on Site': consumer time on site in minutes
# * 'Age': cutomer age in years
# * 'Area Income': Avg. Income of geographical area of consumer
# * 'Daily Internet Usage': Avg. minutes a day consumer is on the internet
# * 'Ad Topic Line': Headline of the advertisement
# * 'City': City of consumer
# * 'Male': Whether or not consumer was male
# * 'Country': Country of consumer
# * 'Timestamp': Time at which consumer clicked on Ad or closed window
# * 'Clicked on Ad': 0 or 1 indicated clicking on Ad

# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = (10,6)

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

from sklearn.metrics import confusion_matrix, classification_report, RocCurveDisplay
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score
from sklearn.model_selection import cross_val_score, cross_validate, train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier, Pool  
from lazypredict.Supervised import LazyClassifier

# %%
df = pd.read_csv("advertising2.csv")
df.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# ...

# %%
df.sample(10)
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 96                      45.72   36     22473.08                154.02
# 301                     52.62   50     73863.25                176.52
# 630                     63.43   29     66504.16                236.75
# 870                     45.82   27     64410.80                171.24
# 310                     76.56   34     70179.11                221.53
# 596                     77.25   27     55901.12                231.38
# 899                     35.66   45     46197.59                151.72
# 166                     66.18   55     28271.84                143.42
# 691                     87.16   37     50711.68                231.95
# 433                     85.23   36     64238.71                212.92
#
#                                    Ad Topic Line            City  Male  \
# 96                Versatile homogeneous capacity    Williammouth     1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.3+ KB

# %%
df.describe().T
# Out:
#                            count     mean      std      min      25%      50%  \
# Daily Time Spent on Site 1000.00    65.00    15.85    32.60    51.36    68.22
# Age                      1000.00    36.01     8.79    19.00    29.00    35.00
# Area Income              1000.00 55000.00 13414.63 13996.50 47031.80 57012.30
# Daily Internet Usage     1000.00   180.00    43.90   104.78   138.83   183.13
# Male                     1000.00     0.48     0.50     0.00     0.00     0.00
# Clicked on Ad            1000.00     0.50     0.50     0.00     0.00     0.50
#
#                               75%      max
# Daily Time Spent on Site    78.55    91.43
# Age                         42.00    61.00
# Area Income              65470.63 79484.80
# Daily Internet Usage       218.79   269.96
# Male                         1.00     1.00
# Clicked on Ad                1.00     1.00

# %%
df["Clicked on Ad"].value_counts()
# Out:
# Clicked on Ad
# 0    500
# 1    500
# Name: count, dtype: int64

# %%
def unique_values(df, columns):
    """Prints unique values and their counts for specific columns in the DataFrame."""

    for column_name in columns:
        print(f"Column: {column_name}\n{'-'*30}")
        unique_vals = df[column_name].unique()
        value_counts = df[column_name].value_counts()
        print(f"Unique Values ({len(unique_vals)}): {unique_vals}\n")
        print(f"Value Counts:\n{value_counts}\n{'='*40}\n")

# %%
cat_features = df.select_dtypes(include="object").columns
cat_features
# Out:
# Index(['Ad Topic Line', 'City', 'Country', 'Timestamp'], dtype='object')

# %%
unique_values(df, cat_features)
# Out:
# Column: Ad Topic Line
# ------------------------------
# Unique Values (1000): ['Cloned 5thgeneration orchestration' 'Monitored national standardization'
#  'Organic bottom-line service-desk'
#  'Triple-buffered reciprocal time-frame' 'Robust logistical utilization'
#  'Sharable client-driven software' 'Enhanced dedicated support'
#  'Reactive local challenge' 'Configurable coherent function'
#  'Mandatory homogeneous architecture' 'Centralized neutral neural-net'
#  'Team-oriented grid-enabled Local Area Network'
#  'Centralized content-based focus group'
#  'Synergistic fresh-thinking array' 'Grass-roots coherent extranet'
#  'Persistent demand-driven interface' 'Customizable multi-tasking website'
#  'Intuitive dynamic attitude'
#  'Grass-roots solution-oriented conglomeration'
#  'Advanced 24/7 productivity' 'Object-based reciprocal knowledgebase'
#  'Streamlined non-volatile analyzer'
#  'Mandatory disintermediate utilization'
# ...

# %%
for feature in df.columns:
    if df[feature].dtype=="object":
        print(feature, df[feature].nunique())
            
# We are identifying the number of unique observations for categorical features.
# We will drop features that contain too many unique categorical observations.
# Tree-based models tend to assign too much importance to features with too many unique categorical observations.
# Also, the model cannot learn much from categorical features that have very few unique observations.
# Out:
# Ad Topic Line 1000
# City 969
# Country 237
# Timestamp 1000

# %%
sns.pairplot(df, hue="Clicked on Ad");

# %%
sns.pairplot(df, hue="Clicked on Ad", corner=True);

# %% [markdown]
# # Modelling

# %% [markdown]
# ## Train | Test Split

# %%
X = df[["Daily Time Spent on Site", "Age", "Area Income", "Daily Internet Usage", "Male"]]
y = df["Clicked on Ad"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# ## AdaBoost Modelling and Model Performance

# %% [markdown]
# **AdaBoost and Its Working Principle**
#
# AdaBoost is a powerful method for learning difficult and complex structures in datasets. By learning from the mistakes of each learner, it creates a model that generally outperforms a single learner. This approach enables more accurate and reliable predictions in machine learning problems.
#
# AdaBoost builds a model by using weak learners (commonly referred to as 'stumps'). Each weak learner is trained sequentially, relying on the performance of the previous one, and they share information to improve the overall performance of the model.

# %% [markdown]
# **Working Principle and Application of AdaBoost**
#
# To better understand the AdaBoost algorithm, we will conduct an experiment by setting the number of trees to 3. This will help us observe the fundamental working logic of AdaBoost and how it operates.
#
#  **AdaBoost's Working Process**
# 1. **Tree Creation:**
#    - AdaBoost creates trees based on the specified `n_estimators` parameter. In our example, this number will be set to 3.
#
# 2. **Weighting and Updating:**
#    - Each tree focuses on a portion of observations that were correctly classified while increasing the weight of misclassified observations.
#    - Subsequent trees focus on harder-to-classify observations.
#
# 3. **Scoring:**
#    - Scores for each tree are calculated. AdaBoost uses these scores to make predictions.
#
#  **Prediction Method**
# - AdaBoost produces a result by weighting the predictions of each tree.
# - Unlike Random Forest, AdaBoost takes the weights of the trees into account. If one class has a higher weight than another, that class is preferred.
# - This weighting method differentiates AdaBoost's prediction process from Random Forest.
#
# AdaBoost's iterative weighting mechanism allows it to focus on difficult observations and improve the overall model accuracy effectively.

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %%
ada_model = AdaBoostClassifier(n_estimators=50, random_state=42) # n_estimators=50 default

# %%
ada_model.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(random_state=42)

# %%
eval_metric(ada_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[41  3]
#  [ 4 52]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92        44
#            1       0.95      0.93      0.94        56
#
#     accuracy                           0.93       100
#    macro avg       0.93      0.93      0.93       100
# weighted avg       0.93      0.93      0.93       100
#
#
# Train_Set
# [[454   2]
#  [ 12 432]]
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       456
#            1       1.00      0.97      0.98       444
#
#     accuracy                           0.98       900
#    macro avg       0.98      0.98      0.98       900
# weighted avg       0.98      0.98      0.98       900

# %%
model = AdaBoostClassifier(n_estimators=50, random_state=42)
scores = cross_validate(model,
                        X_train,
                        y_train,
                        scoring=["accuracy", "precision", "recall", "f1"],
                        cv=10,
                        return_train_score=True)
df_scores = pd.DataFrame(scores, index=range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy     0.96
# train_accuracy    0.99
# test_precision    0.97
# train_precision   1.00
# test_recall       0.95
# train_recall      0.97
# test_f1           0.96
# train_f1          0.99
# dtype: float64

# %%
model = AdaBoostClassifier(n_estimators=3, random_state=42)
model.fit(X_train, y_train) # n_estimators=3, I will create and visualize a model with only 3 trees.
# Out:
# AdaBoostClassifier(n_estimators=3, random_state=42)

# %%
targets = df["Clicked on Ad"].astype("str")
plt.figure(figsize=(8,4),dpi=150)
plot_tree(model.estimators_[0],
          filled=True,
          feature_names=X.columns.to_list(),
          class_names=targets.unique().tolist(),
          fontsize=10);

# %%
targets = df["Clicked on Ad"].astype("str")
plt.figure(figsize=(8,4),dpi=150)
plot_tree(model.estimators_[1],
          filled=True,
          feature_names=X.columns.to_list(),
          class_names=targets.unique().tolist(),
          fontsize=10);

# %%
targets = df["Clicked on Ad"].astype("str")
plt.figure(figsize=(8,4),dpi=150)
plot_tree(model.estimators_[2],
          filled=True,
          feature_names=X.columns.to_list(),
          class_names=targets.unique().tolist(),
          fontsize=10);

# %%
model.estimator_errors_

# Error of the first tree: 0.09666667
# Error of the second tree: 0.15406964
# Error of the third tree: 0.23907436
# Out:
# array([0.09666667, 0.15660636, 0.29526371])

# %%
1/2 * np.log((1-0.09666667)/0.09666667) # First tree's weight
# Out:
# 1.117411476360216

# %%
1/2 * np.log((1-0.15406964)/0.15406964) # Second tree's weight
# Out:
# 0.8515161657212168

# %%
1/2 * np.log((1-0.23907436)/0.23907436) # Third tree's weight
# Out:
# 0.5788805031523857

# %% [markdown]
# **Error Rate Analysis with AdaBoosting Based on Number of Trees**
#
# The steps for analyzing the error rate in the AdaBoosting algorithm based on the number of trees are as follows:
#
# **Steps:**
#
# 1. Define a range for the number of trees (recommended ranges are typically broad values such as 50, 100, 250, 500).
#
# 2. For each specified number of trees, create a separate AdaBoost model and train it on your dataset.
#
# 3. Calculate the f1 score for each model, then subtract it from 1 to find the error rate.
#
# 4. Plot a line graph showing the relationship between the number of trees (x-axis) and the error rate (y-axis). Use this graph to examine how the error rate changes as the number of trees increases.
#
#  **Key Points to Consider:**
# - Instead of choosing very small values for the number of trees, prefer broader ranges (e.g., 50, 100, 250, 500).
# - Identify the lowest point on the graph, which often corresponds to the best-performing model.
# - This process can be time-consuming for large datasets, so be patient.
#
# By following these steps, you can analyze how the number of trees affects the error rate in AdaBoost models.

# %%
error_rates = []
for n in range(1,300):
    model = AdaBoostClassifier(n_estimators=n)
    model.fit(X_train,y_train)
    preds = model.predict(X_test)
    err = 1 - f1_score(y_test,preds)
    error_rates.append(err)

# %%
plt.plot(range(1,300),error_rates)
plt.xticks(range(1,300,20));

# %% [markdown]
# **AdaBoost Hyperparameters**
# AdaBoost is an algorithm that can optimize its performance by carefully adjusting its hyperparameters, especially when working with **weak learners**. Here are the most important hyperparameters of AdaBoost and their explanations:
#
# **Hyperparameter Summary Table**
#
# | **Parameter**       | **Description**                                              | **Default**                      |
# |---------------------|--------------------------------------------------------------|----------------------------------|
# | **n_estimators**    | Total number of trees to be used                             | 50                               |
# | **learning_rate**   | Determines the contribution of each weak learner             | 1.0                              |
# | **base_estimator**  | The base model used as a weak learner                        | DecisionTreeClassifier(max_depth=1) |
# | **algorithm**       | The boosting algorithm to be used                            | 'SAMME.R'                        |
#
# It is important to carefully adjust these hyperparameters to optimize the performance of the AdaBoost model. You can use **cross-validation** and, if necessary, **early stopping** methods to find the right combination of **n_estimators** and **learning_rate**.

# %%
model = AdaBoostClassifier( random_state=42)

# %%
param_grid = {
    "n_estimators": [50, 100, 200, 300, 400],
    "learning_rate": [1, 0.1, 0.01, 0.001],
}

# %%
ada_grid_model = GridSearchCV(model, param_grid, cv=10, n_jobs=-1, verbose=2, scoring="f1")

# %%
ada_grid_model.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# GridSearchCV(cv=10, estimator=AdaBoostClassifier(random_state=42), n_jobs=-1,
#              param_grid={'learning_rate': [1, 0.1, 0.01, 0.001],
#                          'n_estimators': [50, 100, 200, 300, 400]},
#              scoring='f1', verbose=2)

# %%
ada_grid_model.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 300}

# %%
ada_grid_model.best_score_
# Out:
# 0.9680536798662652

# %%
ada_grid_model.best_estimator_
# Out:
# AdaBoostClassifier(learning_rate=0.1, n_estimators=300, random_state=42)

# %%
y_pred = ada_grid_model.predict(X_test)
y_pred_proba = ada_grid_model.predict_proba(X_test)
ada_f1 = f1_score(y_test, y_pred)
ada_recall = recall_score(y_test, y_pred)
ada_auc = roc_auc_score(y_test, y_pred_proba[:,1])
eval_metric(ada_grid_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[41  3]
#  [ 4 52]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92        44
#            1       0.95      0.93      0.94        56
#
#     accuracy                           0.93       100
#    macro avg       0.93      0.93      0.93       100
# weighted avg       0.93      0.93      0.93       100
#
#
# Train_Set
# [[453   3]
#  [ 17 427]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       456
#            1       0.99      0.96      0.98       444
#
#     accuracy                           0.98       900
#    macro avg       0.98      0.98      0.98       900
# weighted avg       0.98      0.98      0.98       900

# %% [markdown]
# ### Feature_Importances

# %%
model = AdaBoostClassifier(learning_rate=1,n_estimators=500, random_state=42)
model.fit(X_train, y_train) 
model.feature_importances_
# Out:
# array([0.318, 0.112, 0.274, 0.29 , 0.006])

# %%
feats = pd.DataFrame(index=X.columns, data= model.feature_importances_, columns=['ada_importance'])
ada_imp_feats = feats.sort_values("ada_importance", ascending = False)
ada_imp_feats
# Out:
#                           ada_importance
# Daily Time Spent on Site            0.32
# Daily Internet Usage                0.29
# Area Income                         0.27
# Age                                 0.11
# Male                                0.01

# %%
plt.figure(figsize=(12, 6))
ax = sns.barplot(data=ada_imp_feats, x=ada_imp_feats.index, y='ada_importance')
ax.bar_label(ax.containers[0], fmt="%.3f")
plt.xticks(rotation=90);

# %%
RocCurveDisplay.from_estimator(ada_grid_model, X_test, y_test);

# %% [markdown]
# ## Gradient Boosting Modelling and Model Performance

# %% [markdown]
# **Gradient Boosting models are based on the principle of creating a strong model by sequentially improving weak learners (e.g., decision trees) prone to making errors. In this process, the errors (residuals) of each learner become the target for improvement by the next learner.**

# %%
grad_model = GradientBoostingClassifier( random_state=42) 
grad_model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
eval_metric(grad_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[41  3]
#  [ 2 54]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94        44
#            1       0.95      0.96      0.96        56
#
#     accuracy                           0.95       100
#    macro avg       0.95      0.95      0.95       100
# weighted avg       0.95      0.95      0.95       100
#
#
# Train_Set
# [[456   0]
#  [  1 443]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       456
#            1       1.00      1.00      1.00       444
#
#     accuracy                           1.00       900
#    macro avg       1.00      1.00      1.00       900
# weighted avg       1.00      1.00      1.00       900

# %%
model = GradientBoostingClassifier(random_state=42)
scores = cross_validate(model, X_train, y_train, scoring = ['accuracy', 'precision','recall',
                                                                   'f1', 'roc_auc'], cv = 10, return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy     0.95
# train_accuracy    1.00
# test_precision    0.96
# train_precision   1.00
# test_recall       0.95
# train_recall      1.00
# test_f1           0.95
# train_f1          1.00
# test_roc_auc      0.99
# train_roc_auc     1.00
# dtype: float64

# %% [markdown]
# ### GridSearch
#
# **Hyperparameter Summary Table**
#
# | **Parameter**          | **Description**                                           | **Default**        |
# |-------------------------|----------------------------------------------------------|--------------------|
# | **loss**               | Loss function used for model optimization                 | 'deviance'         |
# | **learning_rate**       | Learning rate                                             | 0.1                |
# | **n_estimators**        | Number of trees                                           | 100                |
# | **max_depth**           | Maximum depth of each tree                                | 3                  |
# | **min_samples_split**   | Minimum number of samples required to split a node        | 2                  |
# | **min_samples_leaf**    | Minimum number of samples required in a leaf node         | 1                  |
# | **max_features**        | Maximum number of features to consider for a split       | 'sqrt' or 'auto'   |
# | **subsample**           | Subsampling ratio                                        | 1.0                |
# | **criterion**           | Criterion for evaluating splits                          | 'friedman_mse'     |

# %% [markdown]
# **Tips for Tuning Gradient Boosting**
#
# 1. **Balance Between Number of Trees and Learning Rate:**
#    - If you choose a low learning rate (e.g., 0.01), a higher number of trees (`n_estimators`) is needed.
#    - A high learning rate can achieve good results with fewer trees.
#
# 2. **Subsample:**
#    - A value like 0.8 typically reduces variance and improves model performance.
#
# 3. **Max Depth:**
#    - Lower depths (e.g., 2 or 3) generally provide better generalization.
#
# 4. **Cross-Validation:**
#    - Use grid search or random search for hyperparameter optimization.
#
# 5. **Early Stopping:**
#    - Apply early stopping to prevent overfitting.

# %%
param_grid = {
    "n_estimators": [100, 200, 300],
    "subsample": [0.5, 0.8],
    "max_features": [None, 2, 34],
    "learning_rate": [0.01, 0.1, 0.5],
    'max_depth': [3, 4, 5]
}

# %%
gb_model = GradientBoostingClassifier(random_state = 42)
gb_grid = GridSearchCV(gb_model,
                       param_grid,
                       scoring="f1",
                       verbose=2,
                       n_jobs=-1,
                       return_train_score=True).fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits

# %%
gb_grid.best_estimator_
# Out:
# GradientBoostingClassifier(learning_rate=0.01, max_features=2, n_estimators=300,
#                            random_state=42, subsample=0.5)

# %%
gb_grid.best_params_
# Out:
# {'learning_rate': 0.01,
#  'max_depth': 3,
#  'max_features': 2,
#  'n_estimators': 300,
#  'subsample': 0.5}

# %%
y_pred = gb_grid.predict(X_test)
y_pred_proba = gb_grid.predict_proba(X_test)
gb_f1 = f1_score(y_test, y_pred)
gb_recall = recall_score(y_test, y_pred)
gb_auc = roc_auc_score(y_test, y_pred)

eval_metric(gb_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[40  4]
#  [ 2 54]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93        44
#            1       0.93      0.96      0.95        56
#
#     accuracy                           0.94       100
#    macro avg       0.94      0.94      0.94       100
# weighted avg       0.94      0.94      0.94       100
#
#
# Train_Set
# [[451   5]
#  [ 13 431]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       456
#            1       0.99      0.97      0.98       444
#
#     accuracy                           0.98       900
#    macro avg       0.98      0.98      0.98       900
# weighted avg       0.98      0.98      0.98       900

# %% [markdown]
# ### Feature Importances

# %%
model = GradientBoostingClassifier(learning_rate=0.01, max_features=2, n_estimators=300,
                           random_state=42, subsample=0.5)
model.fit(X_train, y_train)

model.feature_importances_

feats = pd.DataFrame(index=X.columns, data=model.feature_importances_, columns=['grad_importance'])
grad_imp_feats = feats.sort_values("grad_importance", ascending= False)
grad_imp_feats
# Out:
#                           grad_importance
# Daily Internet Usage                 0.47
# Daily Time Spent on Site             0.34
# Area Income                          0.10
# Age                                  0.08
# Male                                 0.00

# %%
plt.figure(figsize=(12, 6))
ax = sns.barplot(data=grad_imp_feats,
                 x=grad_imp_feats.index,
                 y='grad_importance')
ax.bar_label(ax.containers[0], fmt="%.3f")
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Daily Internet Usage'),
#   Text(1, 0, 'Daily Time Spent on Site'),
#   Text(2, 0, 'Area Income'),
#   Text(3, 0, 'Age'),
#   Text(4, 0, 'Male')])

# %%
RocCurveDisplay.from_estimator(gb_grid, X_test, y_test);

# %% [markdown]
# ## XGBoost: Extreme Gradient Boosting Modelling and Model Performance
#
# ****XGBoost (eXtreme Gradient Boosting)**
#
# XGBoost is a scalable and optimized version of Gradient Boosting algorithms. It is a powerful machine learning algorithm commonly used for both regression and classification problems. Due to its performance and speed, XGBoost is a preferred method in many machine learning and data science competitions.
#
# **Key Features of XGBoost**
#
# - **Gradient Boosting:**
#   XGBoost utilizes Decision Trees (DT) to make predictions and follows the Gradient Boosting logic. It uses a logistic regression-like approach for classification.
#
# - **Speed and Performance:**
#   XGBoost supports parallel processing and simultaneous creation of tree branches, making it extremely fast and effective for large datasets.
#
# - **Flexibility:**
#   It allows users to define custom optimization objectives and evaluation metrics, increasing adaptability to various prediction problems.
#
# - **Regularization:**
#   XGBoost includes both L1 (lasso) and L2 (ridge) regularization to control model complexity and prevent overfitting.
#
# - **Handling Missing Values:**
#   XGBoost can automatically handle missing data and learn the best branching for such cases.
#
# - **Cross-Validation:**
#   XGBoost has built-in cross-validation, allowing direct performance evaluation at each iteration. The output of XGBoost can be seen as CV-based scores.
#
# - **Feature Importance:**
#   XGBoost provides feature importance values, similar to Random Forest, offering insights into which features are most influential in the model.
#
# - **Differences from Gradient Boosting:**
#   Unlike traditional Gradient Boosting, XGBoost is faster and performs better due to specific optimizations and regularization techniques.
#
# **How Does XGBoost Work?**
#
# 1. **Initial Prediction:**
#    XGBoost starts with an initial prediction for all examples, usually a constant value, which allows the calculation of the first residuals.
#
# 2. **Learning Process:**
#    - In each iteration, XGBoost builds a new tree based on the differences (residuals) between the predictions of all previous trees and the actual values.
#    - The new tree aims to correct the prediction errors of the previous trees.
#    - While adding each tree, XGBoost considers both model fit and regularization by minimizing a loss function, which determines the tree structure and branching points.
#
# 3. **Model Update:**
#    - With each new tree added, the XGBoost model scales the tree's contribution using the learning rate and updates the overall predictions.
#    - This step incrementally improves the model, enabling more accurate predictions.
#
# 4. **Early Stopping:**
#    - XGBoost can halt training when a stopping criterion is met. This often occurs when the error rate on a validation dataset does not improve over a defined period.
#
# XGBoost provides significant advantages in terms of speed, flexibility, and overall performance, especially when working with large datasets and complex prediction problems.

# %%
xgb = XGBClassifier(random_state=42)

# %%
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
eval_metric(xgb, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[40  4]
#  [ 2 54]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93        44
#            1       0.93      0.96      0.95        56
#
#     accuracy                           0.94       100
#    macro avg       0.94      0.94      0.94       100
# weighted avg       0.94      0.94      0.94       100
#
#
# Train_Set
# [[456   0]
#  [  0 444]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       456
#            1       1.00      1.00      1.00       444
#
#     accuracy                           1.00       900
#    macro avg       1.00      1.00      1.00       900
# weighted avg       1.00      1.00      1.00       900

# %% [markdown]
# ### XGBoost Model Tuning - Gridsearch
#
# #### **Hyperparameter Summary Table**
#
# | **Parameter**          | **Description**                                           | **Default**        |
# |-------------------------|----------------------------------------------------------|--------------------|
# | **max_depth**           | Maximum depth of each tree                                | 6                  |
# | **learning_rate**       | Learning rate                                             | 0.3                |
# | **n_estimators**        | Number of boosting iterations (number of trees)           | 100                |
# | **booster**             | Boosting algorithm selection                              | `'gbtree'`         |
# | **min_child_weight**    | Minimum sum of instance weights needed for a split        | 1                  |
# | **gamma**               | Minimum loss reduction required for a split              | 0                  |
# | **subsample**           | Subsampling ratio                                        | 1.0                |
# | **colsample_bytree**    | Ratio of features to select for each tree                 | 1.0                |
# | **reg_alpha**           | L1 regularization term                                    | 0                  |
# | **reg_lambda**          | L2 regularization term                                    | 1                  |
# | **scale_pos_weight**    | Weight of the positive class                              | 1                  |
# | **tree_method**         | Tree construction method                                  | `'auto'`           |
# | **early_stopping_rounds** | Stops training when performance doesn't improve          | Not specified      |
#
#
#
# ### **Tips for Tuning XGBoost**
#
# 1. **Balance Between Number of Trees and Learning Rate:**
#    - A lower learning rate combined with a higher number of trees usually results in better generalization performance.
#
# 2. **Subsample and Colsample:**
#    - Using subsample (e.g., 0.8) and colsample (e.g., 0.8) can help reduce the model's variance.
#
# 3. **Max Depth and Min Child Weight:**
#    - A smaller `max_depth` and higher `min_child_weight` can prevent overfitting.
#
# 4. **Hyperparameter Optimization with Grid Search:**
#    - Use `GridSearchCV` or `RandomizedSearchCV` to find the best combination of hyperparameters.

# %%
param_grid = {
    "n_estimators": [50, 100, 200, 250, 300],
    'max_depth': [3, 4, 5,6,7],
    "learning_rate": [0.1, 0.2, 0.3],
    "subsample": [0.5, 0.8, 1],
    "colsample_bytree": [0.5, 0.7, 1]
}

# %%
xgb_model = XGBClassifier(random_state=42, use_label_encoder=False)

# %%
xgb_grid = GridSearchCV(xgb_model,param_grid=param_grid, cv=5, n_jobs=-1, verbose=2, scoring="f1", return_train_score=True)

# %%
xgb_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 675 candidates, totalling 3375 fits
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
# ...

# %%
y_pred = xgb_grid.predict(X_test)

xgb_f1 = f1_score(y_test, y_pred)
xgb_recall = recall_score(y_test, y_pred)
xgb_auc = roc_auc_score(y_test, y_pred)

eval_metric(xgb_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[40  4]
#  [ 4 52]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91        44
#            1       0.93      0.93      0.93        56
#
#     accuracy                           0.92       100
#    macro avg       0.92      0.92      0.92       100
# weighted avg       0.92      0.92      0.92       100
#
#
# Train_Set
# [[453   3]
#  [ 13 431]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       456
#            1       0.99      0.97      0.98       444
#
#     accuracy                           0.98       900
#    macro avg       0.98      0.98      0.98       900
# weighted avg       0.98      0.98      0.98       900

# %% [markdown]
# ### Feature Importances

# %%
model = XGBClassifier(n_estimators= 50, colsample_bytree = 0.7, subsample= 0.8, learning_rate = 0.1,
                      max_depth= 3, random_state = 42)

model.fit(X_train, y_train)

model.feature_importances_

feats = pd.DataFrame(index=X.columns, data=model.feature_importances_, columns=['xgb_importance'])
xgb_imp_feats = feats.sort_values("xgb_importance", ascending= False)
xgb_imp_feats
# Out:
#                           xgb_importance
# Daily Internet Usage                0.52
# Daily Time Spent on Site            0.28
# Age                                 0.10
# Area Income                         0.09
# Male                                0.02

# %%
RocCurveDisplay.from_estimator(xgb_grid, X_test, y_test);

# %% [markdown]
# # Light GBM (Light Gradient Boosting Machine)
#
# **Light GBM**, developed by Microsoft in 2017, is a type of gradient boosting algorithm designed to improve training time performance compared to XGBoost. It is highly efficient and capable of working with large datasets, making it popular for complex machine learning problems.
#
# **Features of Light GBM**
#
# - **Fast Training and Prediction Times:**
#   Light GBM processes datasets quickly, making it a time-saving option for large datasets. It is not recommended for datasets smaller than 9K–10K due to its tendency to overfit on small datasets. In short, Light GBM is ideal for large datasets.
#
# - **Low Memory Usage:**
#   Thanks to optimization techniques, Light GBM uses less memory compared to other gradient boosting frameworks.
#
# - **High Performance:**
#   Light GBM achieves high accuracy rates with advanced algorithms, often outperforming traditional gradient boosting methods.
#
# - **Support for Special Features:**
#   - Ability to manage missing values in datasets.
#
# > **Note:**
# > Light GBM has over 100 parameters. It is beneficial to review the documentation before implementation to understand these parameters.
#
# **Working Principle of Light GBM**
#
# Unlike other gradient boosting methods, Light GBM grows trees leaf-wise rather than level-wise.
# - This approach divides subsets of the dataset more evenly during training, resulting in fewer errors.
# - As the dataset size increases, the leaf-wise method proves to be more efficient than the level-wise approach.
#
# **Applications of Light GBM**
#
# 1. **Large Datasets:**
#    Light GBM is highly effective on large and complex datasets.
#
# 2. **Applications Requiring High Performance:**
#    Suitable for real-time applications or tasks requiring high accuracy.
#
# 3. **Various Problem Types:**
#    Light GBM can be used for both classification and regression problems.
#
#  **Light GBM in Context**
#
# Gradient Boosting is essentially:
# - **Decision Trees** + **Boosting** + **Gradient Descent**.
#
# LightGBM extends this with:
# - **GOSS (Gradient-based One-Side Sampling)**: Reduces the dataset size during training by selecting instances with large gradients.
# - **EFB (Exclusive Feature Bundling)**: Groups mutually exclusive features into a single feature to reduce feature space.
#
#  **Optimization Parameters in Light GBM**
#
#  To Prevent Overfitting:
# - **`learning_rate`**
# - **`max_depth`**
# - **`num_leaves`**
# - **`min_data_in_leaf`**
#
#  To Speed Up Training:
# - **`feature_fraction`**
# - **`bagging_fraction`**
# - **`num_iterations`**
#
#  **Programming Language Support**
#
# Light GBM is an open-source machine learning library written in **C++**, ensuring high performance. However, it supports various programming languages such as Python, R, and Java through bindings and interfaces, allowing flexibility in implementation.
#
# **Conclusion**
#
# Light GBM is a powerful machine learning tool designed for high efficiency, speed, and accuracy, particularly in large and complex datasets. It is an ideal choice for researchers and developers aiming to achieve effective results in various problems with large datasets.

# %%
lgbm_model = LGBMClassifier(random_state=42)
lgbm_model.fit(X_train, y_train)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 444, number of negative: 456
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001091 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 809
# [LightGBM] [Info] Number of data points in the train set: 900, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.493333 -> initscore=-0.026668
# [LightGBM] [Info] Start training from score -0.026668
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
eval_metric(lgbm_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[42  2]
#  [ 4 52]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93        44
#            1       0.96      0.93      0.95        56
#
#     accuracy                           0.94       100
#    macro avg       0.94      0.94      0.94       100
# weighted avg       0.94      0.94      0.94       100
#
#
# Train_Set
# [[456   0]
#  [  0 444]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       456
#            1       1.00      1.00      1.00       444
#
#     accuracy                           1.00       900
#    macro avg       1.00      1.00      1.00       900
# weighted avg       1.00      1.00      1.00       900

# %%
model = LGBMClassifier(random_state=42)

scores = cross_validate(model,
                        X_train,
                        y_train,
                        scoring=[
                            'accuracy', 'precision_macro', 'recall_macro',
                            'f1_macro', 'roc_auc_ovr'
                        ],
                        cv=10,
                        return_train_score=True)

df_scores = pd.DataFrame(scores, index=range(1, 11))
mean_scores = df_scores.mean()[2:]
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 399, number of negative: 411
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000363 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 809
# [LightGBM] [Info] Number of data points in the train set: 810, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.492593 -> initscore=-0.029632
# [LightGBM] [Info] Start training from score -0.029632
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
print(mean_scores)
# Out:
# test_accuracy           0.96
# train_accuracy          1.00
# test_precision_macro    0.96
# train_precision_macro   1.00
# test_recall_macro       0.96
# train_recall_macro      1.00
# test_f1_macro           0.96
# train_f1_macro          1.00
# test_roc_auc_ovr        0.99
# train_roc_auc_ovr       1.00
# dtype: float64

# %% [markdown]
# ### Light GBM Model Tuning - Gridsearch

# %% [markdown]
# **LightGBM Hyperparameters**
#
# | **Parameter**          | **Description**                                           | **Default**        |
# |-------------------------|----------------------------------------------------------|--------------------|
# | **boosting_type**       | Type of boosting used                                     | `'gbdt'`           |
# | **num_leaves**          | Maximum number of leaves in a tree                       | 31                 |
# | **max_depth**           | Maximum depth of each tree                               | -1 (no limit)      |
# | **learning_rate**       | Learning rate                                            | 0.1                |
# | **n_estimators**        | Number of trees                                          | 100                |
# | **subsample**           | Subsampling ratio                                        | 1.0                |
# | **colsample_bytree**    | Ratio of features used per tree                          | 1.0                |
# | **reg_alpha**           | L1 regularization term                                   | 0.0                |
# | **reg_lambda**          | L2 regularization term                                   | 0.0                |
# | **min_child_weight**    | Minimum sum of instance weights in a leaf                | 0.001              |
# | **min_child_samples**   | Minimum number of samples required in a leaf             | 20                 |
#
# ---
# **Tips for Tuning LightGBM**
#
# 1. **Balance Between Learning Rate and Number of Trees:**
#    - A lower learning rate combined with a higher number of trees (`n_estimators`) generally results in better performance.
#
# 2. **Num Leaves and Max Depth:**
#    - The `num_leaves` value should be compatible with `max_depth`. Higher values increase model capacity but also the risk of overfitting.
#
# 3. **Regularization:**
#    - Use `reg_alpha` and `reg_lambda` to limit model complexity and prevent overfitting.
#
# 4. **Subsample and Colsample:**
#    - Setting `subsample` (e.g., 0.8) and `colsample_bytree` (e.g., 0.8) often leads to better generalization.
#
# 5. **Tuning with Grid Search:**
#    - Optimize hyperparameters using `GridSearchCV` or `RandomizedSearchCV` for the best combination.

# %%
param_grid = {
    'learning_rate': [0.1, 1],
    'n_estimators': [50, 100, 200, 250],
    'num_leaves': [20, 30, 50, 70],  
    'max_depth': [-1, 3, 4, 5, 7],     
    'subsample': [0.5, 0.8, 1.0],
    'colsample_bytree': [0.8, 1.0]
}

# %%
lgbm_model = LGBMClassifier(random_state=42)
lgbm_grid = GridSearchCV(estimator=lgbm_model,
                         param_grid=param_grid,
                         cv=5,
                         scoring='f1',
                         n_jobs=-1,
                         return_train_score=True).fit(X_train, y_train)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 444, number of negative: 456
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000401 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 809
# [LightGBM] [Info] Number of data points in the train set: 900, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.493333 -> initscore=-0.026668
# [LightGBM] [Info] Start training from score -0.026668
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
lgbm_grid.best_params_
# Out:
# {'colsample_bytree': 0.8,
#  'learning_rate': 0.1,
#  'max_depth': 5,
#  'n_estimators': 50,
#  'num_leaves': 20,
#  'subsample': 0.5}

# %%
y_pred = lgbm_grid.predict(X_test)

lgbm_f1 = f1_score(y_test, y_pred)
lgbm_recall = recall_score(y_test, y_pred)
lgbm_auc = roc_auc_score(y_test, y_pred)

eval_metric(lgbm_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[41  3]
#  [ 4 52]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92        44
#            1       0.95      0.93      0.94        56
#
#     accuracy                           0.93       100
#    macro avg       0.93      0.93      0.93       100
# weighted avg       0.93      0.93      0.93       100
#
#
# Train_Set
# [[455   1]
#  [  9 435]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       456
#            1       1.00      0.98      0.99       444
#
#     accuracy                           0.99       900
#    macro avg       0.99      0.99      0.99       900
# weighted avg       0.99      0.99      0.99       900

# %% [markdown]
# ### Feature Importances

# %%
model = LGBMClassifier(random_state=42, colsample_bytree = 0.8, subsample= 0.5, 
                       n_estimators= 50,num_leaves= 20, max_depth= 5)
model.fit(X_train, y_train)

model.feature_importances_

feats = pd.DataFrame(index=X.columns, data=model.feature_importances_, columns=['lgbm_importance'])
lgbm_imp_feats = feats.sort_values("lgbm_importance", ascending= False)
lgbm_imp_feats
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 444, number of negative: 456
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000560 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 809
# [LightGBM] [Info] Number of data points in the train set: 900, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.493333 -> initscore=-0.026668
# [LightGBM] [Info] Start training from score -0.026668
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
lgbm_grid.best_estimator_
# Out:
# LGBMClassifier(colsample_bytree=0.8, max_depth=5, n_estimators=50,
#                num_leaves=20, random_state=42, subsample=0.5)

# %%
plt.figure(figsize=(12,6))
ax = sns.barplot(data=lgbm_imp_feats, x=lgbm_imp_feats.index, y='lgbm_importance')
ax.bar_label(ax.containers[0],fmt="%.3f")
plt.xticks(rotation=9);

# %%
RocCurveDisplay.from_estimator(lgbm_grid, X_test, y_test);

# %%
import tensorflow as tf
# CUDA destekli GPU var mı kontrol et
print("CUDA Supported GPU Available: ", tf.config.list_physical_devices('GPU'))
# Out:
# CUDA Supported GPU Available:  []

# %% [markdown]
# ## CatBoost (Categorical Boosting)

# %% [markdown]
# **CatBoost (Categorical Boosting Machine)**
#
# **CatBoost**, developed by Yandex, is a **gradient boosting** algorithm specifically optimized for handling **categorical data**. It performs exceptionally well in both classification and regression tasks and requires fewer hyperparameter adjustments compared to other boosting algorithms. Named after **Categorical Boosting**, it aims to overcome the limitations of traditional gradient boosting methods.
#
#  **Features of CatBoost**
#
# **1. Categorical Data Support**
# CatBoost can process categorical features directly. There is no need for manual encoding methods like one-hot or label encoding. It uses a built-in **target encoding** mechanism that minimizes the risk of overfitting.
#
# **2. Robust to Noise**
# CatBoost employs a mechanism called **Ordered Boosting** to prevent overfitting. This technique enhances generalization by ensuring that the model makes accurate predictions based on past data during training.
#
# **3. GPU Support**
# CatBoost can leverage GPUs for training, significantly reducing training time for large datasets.
#
# **4. High Performance with Default Parameters**
# CatBoost delivers excellent performance with default settings, making it effective even with minimal hyperparameter tuning.
#
# **5. Support for Missing Values**
# CatBoost can handle missing values directly, eliminating the need for preprocessing steps.
#
# **6. Explainability**
# CatBoost provides tools to enhance model interpretability, such as:
# - **Feature Importance**: Identifies the most influential features.
# - **SHAP (SHapley Additive Explanations)**: Analyzes the contribution of features to predictions.
#
# **How CatBoost Works**
#
# CatBoost differs from other gradient boosting methods by using **Ordered Boosting**, which improves generalization and reduces overfitting.
#
# Additionally, CatBoost:
# - Optimizes the Gradient Boosting algorithm.
# - Performs exceptionally well with sequential data.
# - Offers high accuracy with shorter training times for large datasets.
#
#
# - **Categorical Data Support**: No manual processing required for categorical features.
# - **Overfitting Control**: Low overfitting risk due to ordered boosting and regularization mechanisms.
# - **Fast and Efficient**: Offers parallel processing and GPU support for speed.
# - **Explainability**: Tools like feature importance and SHAP make it easier to understand the model’s internal workings.
# - **Missing Data Support**: Automatically handles missing values.
# **Limitations of CatBoost**
#
# - **Slower on Small Datasets**: CatBoost may not be as fast as XGBoost or LightGBM on smaller datasets.
# - **GPU Setup**: Requires proper hardware and software compatibility for GPU usage.
# - **Hyperparameter Optimization**: Although effective with default parameters, larger datasets may require tuning for optimal performance.
#
# ---
#  **Comparison: CatBoost vs. XGBoost vs. LightGBM**
#
# | **Feature**            | **CatBoost**               | **XGBoost**           | **LightGBM**         |
# |-------------------------|----------------------------|-----------------------|----------------------|
# | **Categorical Data**    | Built-in support (automatic encoding) | Requires manual encoding | Requires manual encoding |
# | **Overfitting Control** | Ordered Boosting           | L1 and L2 Regularization | Leaf-wise growth    |
# | **Speed**               | Moderate                  | Fast (better with GPU) | Very fast            |
# | **GPU Support**         | Yes                       | Yes                   | Yes                 |
# | **Missing Data**        | Automatically handled      | Requires manual handling | Requires manual handling |
#
# **Conclusion**
#
# **CatBoost** is a powerful gradient boosting algorithm designed for high accuracy and efficiency, particularly in datasets with categorical features. With its ability to handle categorical data directly, reduce overfitting through ordered boosting, and deliver competitive performance even with default settings, CatBoost stands out as a top choice for medium to large datasets featuring categorical data.
#
# **GBM = Decision Tree + Boosting + Gradient Descent**
# **CatBoost = GBM + Ordered Boosting + Categorical Encoding**

# %% [markdown]
# ### **Ordered Boosting in CatBoost**
#
# **Ordered Boosting** is one of the core innovations of the **CatBoost** algorithm, designed to reduce the risk of **overfitting** during model training. This method addresses a key flaw in traditional gradient boosting algorithms.
# **Why Is Ordered Boosting Necessary?**
#
# Classic gradient boosting methods (e.g., XGBoost, LightGBM) can suffer from **data leakage** while learning new features from trees during training. This often leads to overfitting, where the model aligns too closely with the training data rather than generalizing to unseen data.
#
# **The Problem:**
# - Standard boosting methods use the entire dataset during each iteration to make predictions.
# - This can result in the model "leaking" information about the dataset, causing it to overfit to the training data instead of generalizing to test data.
#
# ---
# **How Ordered Boosting Works**
#
# **Ordered Boosting** avoids data leakage by ensuring that during training, only a subset of "past data" is used to predict each sample. This technique helps the model generalize better.
#
# **Steps:**
# 1. Training data is processed sequentially.
# 2. For each data point, the model only uses **prior data points** (its "history") for prediction. Data that hasn't been seen yet is excluded from the process.
# 3. This ensures that no future information is used to predict the current data point.
#
# **Example:**
# Consider training data in the sequence:
# \[ A, B, C, D, E \]
#
# - **Standard Boosting:**
#   - All data points \[A, B, C, D, E\] are used at every step.
# - **Ordered Boosting:**
#   - While predicting:
#     - \(A\): No data is used (it's the first point).
#     - \(B\): Only \(A\) is used.
#     - \(C\): \(A\) and \(B\) are used.
#     - \(D\): \(A, B, C\) are used.
#     - \(E\): \(A, B, C, D\) are used.
#
#  **Advantages of Ordered Boosting**
#
# 1. **Reduces Overfitting:**
#    - Prevents data leakage, improving the model’s ability to generalize.
# 2. **Works Better with Categorical Data:**
#    - Reduces the overfitting risk that can occur during **target encoding** of categorical features.
# 3. **Improved Accuracy:**
#    - Provides more reliable predictions in sequential or time-series problems.
#
# ---
# **Comparison: Ordered Boosting vs. Classic Boosting**
#
# | **Feature**             | **Classic Boosting**            | **Ordered Boosting**          |
# |--------------------------|----------------------------------|-------------------------------|
# | **Data Usage**           | Uses all data points            | Uses only prior data points   |
# | **Data Leakage Risk**    | High                            | Eliminated                   |
# | **Overfitting Risk**     | Higher                          | Lower                        |
# | **Performance**          | Faster                          | Slightly slower              |
#
#  **Conclusion**
#
# **Ordered Boosting** is a standout innovation in the CatBoost algorithm. By preventing data leakage during training, it ensures better generalization and reduces the risk of overfitting. This makes CatBoost particularly advantageous for datasets with sequential or categorical data, offering a significant edge over other gradient boosting methods.

# %% [markdown]
# ### **What is Target Encoding?**
#
# **Target Encoding** is a technique used to convert categorical variables into numerical values by representing each categorical class with a **statistical property** (usually the mean) of a **target variable**.
#
# This method is particularly useful and effective for variables with **high cardinality** (many unique categorical values).
#
# **How Does It Work?**
#
# - For each category in a categorical column, a statistical measure of the target variable is calculated:
#   - **Mean of the target variable**: The most common approach.
#   - Other measures like median, mode, or sum can also be used.
# - For example, consider a categorical variable "City" and a target variable "House Price" (in a regression problem). The category "New York" would be represented by the average house price in New York.
#
# **Steps of Target Encoding**
#
# 1. Analyze the relationship between each class of the categorical variable and the target variable.
# 2. Replace each class with a statistical property of the target variable (e.g., mean).
# 3. Transform the categorical variable into numerical values based on these statistics.
#
# ---
#
# **Example**
#
#  **Data:**
#
# | City        | Price      |
# |-------------|------------|
# | New York    | 500,000    |
# | New York    | 550,000    |
# | Los Angeles | 400,000    |
# | Los Angeles | 420,000    |
# | Chicago     | 300,000    |
#
#  **Target Encoding Result:**
#
# | City        | Encoded_City |
# |-------------|--------------|
# | New York    | 525,000      |
# | New York    | 525,000      |
# | Los Angeles | 410,000      |
# | Los Angeles | 410,000      |
# | Chicago     | 300,000      |
#
# - **New York** → (500,000 + 550,000) / 2 = 525,000
# - **Los Angeles** → (400,000 + 420,000) / 2 = 410,000
# - **Chicago** → 300,000 (single example, so its value remains unchanged).
#
# **Advantages of Target Encoding**
#
# 1. **Supports High Cardinality:**
#    It uses less memory compared to **one-hot encoding** when there are many unique categories.
#
# 2. **Preserves Information:**
#    It retains the relationship between the categorical variable and the target variable.
#
# 3. **Can Improve Model Performance:**
#    Certain machine learning models (especially tree-based models) benefit from target encoding.
#
# **Note:**
# While target encoding is a powerful technique, it should be used carefully to avoid **data leakage**. During training, ensure that the encoding for each data point is based only on the data from the training set and does not include information from the test set or the same data point.

# %%
df2 = df.copy()

# %%
df2 = df2.drop(["Ad Topic Line", "Timestamp"], axis=1)

# %%
X2, y2 = df2.drop("Clicked on Ad", axis=1), df2["Clicked on Ad"]

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.1, random_state=42)

# %%
categorical_features =list(X_train2.select_dtypes(include="object").columns)
categorical_features
# Out:
# ['City', 'Country']

# %%
from catboost import CatBoostClassifier, Pool

# %%
import numpy as np
import catboost

print("NumPy version:", np.__version__)
print("CatBoost version:", catboost.__version__)
# Out:
# NumPy version: 1.26.3
# CatBoost version: 1.2.7

# %%
train_pool = Pool(X_train2, y_train2, cat_features = categorical_features)
test_pool = Pool(X_test2, y_test2, cat_features = categorical_features)

# %%
cat_model = CatBoostClassifier(n_estimators=500, random_state=42) # n_estimators=500 default

# %%
cat_model.fit(X_train2, y_train2, cat_features=categorical_features, verbose=False)

# %%
cat_model.fit(X_train2, y_train2, cat_features=categorical_features, verbose=False, eval_set=(X_test2, y_test2), plot=True)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))

# %%
eval_metric(cat_model, X_train2, y_train2, X_test2, y_test2)
# Out:
# Test_Set
# [[40  4]
#  [ 3 53]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92        44
#            1       0.93      0.95      0.94        56
#
#     accuracy                           0.93       100
#    macro avg       0.93      0.93      0.93       100
# weighted avg       0.93      0.93      0.93       100
#
#
# Train_Set
# [[453   3]
#  [ 15 429]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       456
#            1       0.99      0.97      0.98       444
#
#     accuracy                           0.98       900
#    macro avg       0.98      0.98      0.98       900
# weighted avg       0.98      0.98      0.98       900

# %%
# CatBoost model
cat_model = CatBoostClassifier(n_estimators=500, random_state=42, cat_features=categorical_features, verbose=0)
# Cross-validation
scores = cross_validate(
    cat_model,
    X_train2,
    y_train2,
    scoring=['accuracy', 'precision', 'recall', 'f1', 'roc_auc'],
    cv=5,
    return_train_score=True,
    # fit_params={'cat_features': categorical_features}  # CatBoost için kategorik özellikler burada tanımlanır
)
df_scores = pd.DataFrame(scores, index=range(1, 6))
print(df_scores.mean()[2:])
# Out:
# test_accuracy     0.96
# train_accuracy    0.99
# test_precision    0.97
# train_precision   1.00
# test_recall       0.95
# train_recall      0.98
# test_f1           0.96
# train_f1          0.99
# test_roc_auc      0.99
# train_roc_auc     1.00
# dtype: float64

# %% [markdown]
# ### CatBoost Model Tuning - Gridsearch

# %% [markdown]
# **CatBoost Hyperparameter Summary Table**
#
# | **Parameter**          | **Description**                                      | **Default**      |
# |-------------------------|----------------------------------------------------|------------------|
# | **boosting_type**       | Type of boosting                                   | 'Plain'          |
# | **iterations**          | Number of iterations                               | 1000             |
# | **learning_rate**       | Learning rate                                      | Automatic        |
# | **depth**               | Tree depth                                         | 6                |
# | **l2_leaf_reg**         | L2 regularization coefficient                      | 3.0              |
# | **loss_function**       | Loss function used for optimization                | 'Logloss'        |
# | **cat_features**        | List of categorical features                       | Must be specified|
# | **task_type**           | Device on which the model will run (CPU or GPU)    | 'CPU'            |
# | **early_stopping_rounds** | Early stopping during training                    | None             |
# | **subsample**           | Subsampling ratio                                  | 1.0              |
# | **border_count**        | Number of bins for numerical features              | 254              |

# %%
param_grid = {
    'learning_rate': [0.05, 0.1],                # Learning rate (narrower range)
    'iterations': [200, 500],                   # Number of trees (narrower range)
    'depth': [4, 6],                             # Maximum tree depth (narrower range)
    'l2_leaf_reg': [1, 3],                      # L2 regularization (narrower range)
    'bagging_temperature': [0.0, 1.0],           # Bagging temperature (narrower range)
    'grow_policy': ['Depthwise', 'Lossguide'],   # Tree growing policy (fixed)
    'early_stopping_rounds': [50]               # Number of early stopping rounds (added)
}

# %%
cat_model = CatBoostClassifier(random_state=42, verbose=0, cat_features=categorical_features)

# %%
cat_grid = GridSearchCV(estimator=cat_model,
                        param_grid=param_grid,
                        cv=5,
                        scoring='f1',
                        n_jobs=-1,
                        return_train_score=True,
                        ).fit(X_train2, y_train2)

# %%
def eval_metric2(model, X_train2, y_train2, X_test2, y_test2, cat_features):
    """
    Prints the confusion matrix and classification report for the train and test sets of a CatBoost model.
    Args:
        model: Trained CatBoost model.
        X_train2: Training dataset.
        y_train2: Training labels.
        X_test2: Test dataset.
        y_test2: Test labels.
        cat_features: Names of the categorical features.
    """
    # Predictions for the training set
    train_pool = Pool(X_train2, y_train2, cat_features=cat_features)
    y_train_pred = model.predict(train_pool)
    # Predictions for the test set
    test_pool = Pool(X_test2, y_test2, cat_features=cat_features)
    y_pred = model.predict(test_pool)
    print("Test_Set")
    print(confusion_matrix(y_test2, y_pred))
    print(classification_report(y_test2, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train2, y_train_pred))
    print(classification_report(y_train2, y_train_pred))

# %%
y_pred = cat_grid.predict(test_pool)
cat_f1 = f1_score(y_test2, y_pred)
cat_recall = recall_score(y_test2, y_pred)
cat_auc = roc_auc_score(y_test2, y_pred)
eval_metric2(cat_grid, X_train2, y_train2, X_test2, y_test2, categorical_features)
# Out:
# Test_Set
# [[40  4]
#  [ 4 52]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91        44
#            1       0.93      0.93      0.93        56
#
#     accuracy                           0.92       100
#    macro avg       0.92      0.92      0.92       100
# weighted avg       0.92      0.92      0.92       100
#
#
# Train_Set
# [[456   0]
#  [  1 443]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       456
#            1       1.00      1.00      1.00       444
#
#     accuracy                           1.00       900
#    macro avg       1.00      1.00      1.00       900
# weighted avg       1.00      1.00      1.00       900

# %% [markdown]
# ### Feature Importance

# %%
model = CatBoostClassifier(bagging_temperature= 0.0, depth= 6, early_stopping_rounds= 50, grow_policy= "Lossguide", iterations= 200, l2_leaf_reg= 1, learning_rate= 0.05, random_state=42, verbose=0)
model.fit(train_pool)
model.feature_importances_
feats = pd.DataFrame(index=X_train2.columns, data=model.feature_importances_, columns=['cat_importance'])
cat_imp_feats = feats.sort_values("cat_importance", ascending=False)
cat_imp_feats
# Out:
#                           cat_importance
# Daily Internet Usage               53.97
# Daily Time Spent on Site           27.74
# Area Income                         7.88
# Age                                 5.85
# Country                             3.28
# Male                                1.08
# City                                0.20

# %%
plt.figure(figsize=(12, 6))
ax = sns.barplot(data=cat_imp_feats, x=cat_imp_feats.index, y='cat_importance')
ax.bar_label(ax.containers[0], fmt="%.3f")
plt.xticks(rotation=90);

# %%
RocCurveDisplay.from_estimator(cat_grid, test_pool, y_test2);

# %% [markdown]
# ## Random Forests

# %%
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train,y_train)
y_pred = rf_model.predict(X_test)
rf_f1 = f1_score(y_test, y_pred)
rf_recall = recall_score(y_test, y_pred)
rf_auc = roc_auc_score(y_test, y_pred)
eval_metric(rf_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[41  3]
#  [ 2 54]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94        44
#            1       0.95      0.96      0.96        56
#
#     accuracy                           0.95       100
#    macro avg       0.95      0.95      0.95       100
# weighted avg       0.95      0.95      0.95       100
#
#
# Train_Set
# [[456   0]
#  [  0 444]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       456
#            1       1.00      1.00      1.00       444
#
#     accuracy                           1.00       900
#    macro avg       1.00      1.00      1.00       900
# weighted avg       1.00      1.00      1.00       900

# %% [markdown]
# ## Decision Tree

# %%
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)
y_pred = dt_model.predict(X_test)
dt_f1 = f1_score(y_test, y_pred)
dt_recall = recall_score(y_test, y_pred)
dt_auc = roc_auc_score(y_test, y_pred)
eval_metric(dt_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[38  6]
#  [ 2 54]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.86      0.90        44
#            1       0.90      0.96      0.93        56
#
#     accuracy                           0.92       100
#    macro avg       0.93      0.91      0.92       100
# weighted avg       0.92      0.92      0.92       100
#
#
# Train_Set
# [[456   0]
#  [  0 444]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       456
#            1       1.00      1.00      1.00       444
#
#     accuracy                           1.00       900
#    macro avg       1.00      1.00      1.00       900
# weighted avg       1.00      1.00      1.00       900

# %% [markdown]
# ## Logistic Regression

# %%
scaler = MinMaxScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
log_model=LogisticRegression()
log_model.fit(X_train_scaled, y_train)
y_pred=log_model.predict(X_test_scaled)
log_f1 = f1_score(y_test, y_pred)
log_recall = recall_score(y_test, y_pred)
log_auc = roc_auc_score(y_test, y_pred)
eval_metric(log_model, X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
# Test_Set
# [[43  1]
#  [ 3 53]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96        44
#            1       0.98      0.95      0.96        56
#
#     accuracy                           0.96       100
#    macro avg       0.96      0.96      0.96       100
# weighted avg       0.96      0.96      0.96       100
#
#
# Train_Set
# [[451   5]
#  [ 22 422]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       456
#            1       0.99      0.95      0.97       444
#
#     accuracy                           0.97       900
#    macro avg       0.97      0.97      0.97       900
# weighted avg       0.97      0.97      0.97       900

# %% [markdown]
# ## KNN

# %%
knn_model = KNeighborsClassifier()
knn_model.fit(X_train_scaled, y_train)
y_pred = knn_model.predict(X_test_scaled)
knn_f1 = f1_score(y_test, y_pred)
knn_recall = recall_score(y_test, y_pred)
knn_auc = roc_auc_score(y_test, y_pred)
eval_metric(knn_model, X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
# Test_Set
# [[42  2]
#  [ 2 54]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        44
#            1       0.96      0.96      0.96        56
#
#     accuracy                           0.96       100
#    macro avg       0.96      0.96      0.96       100
# weighted avg       0.96      0.96      0.96       100
#
#
# Train_Set
# [[454   2]
#  [ 24 420]]
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       456
#            1       1.00      0.95      0.97       444
#
#     accuracy                           0.97       900
#    macro avg       0.97      0.97      0.97       900
# weighted avg       0.97      0.97      0.97       900

# %% [markdown]
# ## SVM

# %%
svm_model = SVC()
svm_model.fit(X_train_scaled, y_train)
y_pred = svm_model.predict(X_test_scaled)
svc_f1 = f1_score(y_test, y_pred)
svc_recall = recall_score(y_test, y_pred)
svc_auc = roc_auc_score(y_test, y_pred)
eval_metric(svm_model, X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
# Test_Set
# [[42  2]
#  [ 2 54]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        44
#            1       0.96      0.96      0.96        56
#
#     accuracy                           0.96       100
#    macro avg       0.96      0.96      0.96       100
# weighted avg       0.96      0.96      0.96       100
#
#
# Train_Set
# [[450   6]
#  [ 17 427]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       456
#            1       0.99      0.96      0.97       444
#
#     accuracy                           0.97       900
#    macro avg       0.97      0.97      0.97       900
# weighted avg       0.97      0.97      0.97       900

# %% [markdown]
# ## Comparing Models

# %%
compare = pd.DataFrame({"Model": ["Logistic Regression", "KNN", "SVM", "Decision Tree", "Random Forest", "AdaBoost",
                                 "GradientBoost", "XGBoost", "LightGBM", "CatBoost"],
                        "F1": [log_f1, knn_f1, svc_f1, dt_f1, rf_f1, ada_f1, gb_f1, xgb_f1, lgbm_f1, cat_f1],
                        "Recall": [log_recall, knn_recall, svc_recall, dt_recall, rf_recall, ada_recall, gb_recall, xgb_recall, lgbm_recall, cat_recall],
                        "ROC_AUC": [log_auc, knn_auc, svc_auc, dt_auc, rf_auc, ada_auc, gb_auc, xgb_auc, lgbm_auc, cat_auc]})

def labels(ax):
    for p in ax.patches:
        width = p.get_width()                        # get bar length
        ax.text(width,                               # set the text at 1 unit right of the bar
                p.get_y() + p.get_height() / 2,      # get Y coordinate + X coordinate / 2
                '{:1.3f}'.format(width),             # set variable to display, 2 decimals
                ha = 'left',                         # horizontal alignment
                va = 'center')                       # vertical alignment
    
plt.figure(figsize=(14,10))
plt.subplot(311)
compare = compare.sort_values(by="F1", ascending=False)
ax=sns.barplot(x="F1", y="Model", data=compare, palette="magma")
labels(ax)

plt.subplot(312)
compare = compare.sort_values(by="Recall", ascending=False)
ax=sns.barplot(x="Recall", y="Model", data=compare, palette="magma")
labels(ax)

plt.subplot(313)
compare = compare.sort_values(by="ROC_AUC", ascending=False)
ax=sns.barplot(x="ROC_AUC", y="Model", data=compare, palette="magma")
labels(ax)
plt.show()

# %% [markdown]
# ### **Lazy Predict Library**
#
# **LazyPredict** is a Python library designed to quickly experiment with and compare machine learning models. This library is particularly useful during the model selection phase in data science and machine learning projects, helping save time and effort.
#
#  **How It Works**
#
# - **Automatic Model Testing:** LazyPredict allows you to try multiple classification or regression models automatically, helping you identify which model performs best for your dataset.
# - **Ease of Use:** With minimal coding, you can test numerous models with a single command.
# - **Result Comparison:** It generates a report comparing various models' performance based on metrics like accuracy, F1 score, etc.
#
# **Advantages**
#
# 1. **Time-Saving:** Instead of manually testing multiple machine learning models, LazyPredict automates the process, saving significant time.
# 2. **Starting Point:** Quickly identify promising models for your dataset, providing a foundation for further optimization and analysis.
# 3. **User-Friendly:** Simplifies complex model selection processes, making it ideal for beginners in machine learning.
# 4. **Wide Model Support:** Supports many popular classification and regression models, enabling you to try different types of algorithms easily.
#
# **Disadvantages**
#
# 1. **Limited Customization:** LazyPredict evaluates models with default parameters, meaning detailed hyperparameter tuning is not performed.
# 2. **Special Cases:** It may not handle complex datasets or unique modeling requirements effectively.
# 3. **Performance Metrics:** Results are limited to default parameters, so even the best-performing model may require manual adjustments for optimal performance.

# %%
from lazypredict.Supervised import LazyClassifier

# %%
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)

models, predictions = clf.fit(X_train, X_test, y_train, y_test)

models
# Out:
# 100%|██████████| 31/31 [00:01<00:00, 19.86it/s]
# [LightGBM] [Info] Number of positive: 444, number of negative: 456
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000079 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 810
# [LightGBM] [Info] Number of data points in the train set: 900, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.493333 -> initscore=-0.026668
# [LightGBM] [Info] Start training from score -0.026668
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None) 
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████| 31/31 [00:01<00:00, 21.62it/s]
# [LightGBM] [Info] Number of positive: 444, number of negative: 456
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000083 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 810
# [LightGBM] [Info] Number of data points in the train set: 900, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.493333 -> initscore=-0.026668
# [LightGBM] [Info] Start training from score -0.026668
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# **Linear Models**
#
# 1. **LinearSVC**: Constructs a linear hyperplane for classification.
# 2. **LogisticRegression**: A linear model used for binary or multiclass classification, capable of probability estimation.
# 3. **RidgeClassifier**: An adaptation of ridge regression for classification using L2 regularization.
# 4. **Perceptron**: A simple linear classifier forming the basis of multilayer networks.
# 5. **PassiveAggressiveClassifier**: A fast, low-memory model for online learning, operating in either a passive or aggressive mode.
# 6. **SGDClassifier**: A linear classifier using stochastic gradient descent.
#
#
# # **Support Vector Machines**
#
# 7. **NuSVC**: An alternative version of nonlinear support vector machines with flexible parameterization.
# 8. **SVC**: The general version of support vector machines for both linear and nonlinear classification.
#
# **Discriminant Analysis**
#
# 9. **LinearDiscriminantAnalysis**: Constructs linear boundaries to differentiate between two or more classes.
# 10. **QuadraticDiscriminantAnalysis**: A generalized version of LDA for nonlinear boundaries.
#
# **Tree-Based & Ensemble Models**
#
# 11. **DecisionTreeClassifier**: Creates splits on data to classify using decision trees.
# 12. **ExtraTreeClassifier**: A fast and simple decision tree algorithm with random splits.
# 13. **ExtraTreesClassifier**: An ensemble model combining multiple decision trees with randomly selected features.
# 14. **RandomForestClassifier**: An ensemble of decision trees providing better general performance.
# 15. **BaggingClassifier**: Forms an ensemble by running the same model (e.g., decision trees) on subsets of the data.
# 16. **AdaBoostClassifier**: Iteratively learns by weighting decision trees in an ensemble.
# 17. **XGBClassifier**: Optimizes performance using the XGBoost algorithm with gradient boosting.
# 18. **LGBMClassifier**: Leverages the LightGBM algorithm, optimized for large datasets.
#
# **Naive Bayes Models**
#
# 19. **GaussianNB**: A Naive Bayes classifier for continuous features.
# 20. **BernoulliNB**: A Naive Bayes classifier for binary features.
#
# **Nearest Neighbor Models**
#
# 21. **KNeighborsClassifier**: Classifies data points based on their neighbors.
# 22. **NearestCentroid**: Uses the centroid of each class for classification.
#
#  **Probabilistic Graphical Models**
#
# 23. **LabelPropagation**: Performs classification using graph-based propagation methods.
# 24. **LabelSpreading**: An improved, more flexible version of LabelPropagation.
#
# **Others**
#
# 25. **CalibratedClassifierCV**: A classifier that calibrates predictions to probabilities.
# 26. **PassiveAggressiveClassifier**: Performs online learning on high-dimensional data.
# 27. **DummyClassifier**: A baseline model that classifies using random or simple rules.
